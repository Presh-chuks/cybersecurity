# %%
import math
from math import  factorial, log10, pi, sqrt, prod,floor,trunc
 
 # Factorial example 1 (find factorial 4)
a = 4 
print(factorial(a))

#exaple 2 (simplify)
b = 8 
c = 5
factorial(b) / factorial(c)

#log10 example 1 
log10(1000)

# example 2 (log10 using power rule)
num = 3**2
print (log10(num))

# PI Example 1 (find the area of a circle with radius 5)
p = pi * 5**2
print(p)

# find the circumference of radius = 7cm
Circum = 2 * pi * 7
print(Circum)

#Sqrt Example 1 
num2 = sqrt(72)
print(num2)


#Product example 1
numbers = [5,7,8,9,21,30]
product = prod(numbers)
print(product)
 
#example 2 
num3 = (3*2)
num4 = (4*5)
sum = num3 * num4
print(sum)

f = 2000
pecern = 6/100
percentage = f * pecern
print(percentage)
# Out:
# 24
# 0.9542425094393249
# 78.53981633974483
# 43.982297150257104
# 8.48528137423857
# 1587600
# 120
# 120.0
# 20416
# 12250.0

# %%
#finding pricipal 
year = 1
rate = 12 
ratepercent= rate * 1/ 100
interest = 2450
interestpercent = interest * 100
ratepercentage = ratepercent * 100
principal =  interestpercent / ratepercentage 
print(floor((principal)))
 
#find the interest for 5 years
I = principal * 12 * 5 / 100
print(I)
# Out:
# 20416
# 12250.0

# %%
# writh a program to display the multiplication table for 2,3,4,5,6,7,8,9
# write a program that will display: i love python 500 times 
# build a game that allows users to guess a number and tell them whether the or the number is right or wrong or close guess

# %%
#list
numbers = [2,4,3,6,4,7,1,8,2,0,4,6,3,5]
name = ["cybergate","abel"," naprima","precious" ]

#dict 
result = { 'name': "obinna", "score":76, "remark": "pass","comment": "satisfactory"}
for i in result: 
    #print(result[i])
    #print(f"{1}: {result[i]}")
    print(i, result[i], sep= " = ")
# Out:
# name = obinna
# score = 76
# remark = pass
# comment = satisfactory

# %%
# %pip install requests                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
import requests 
requests.get('https://jsonplaceholder.typeicode.com/users')
import tkinter
