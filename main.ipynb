# %%
import os
#help(os)

# %%
# print(5//2)
9 != 9 | False and 7 > 5 & 10 > 5
# Out:
# False

# %%
print(2*3)
print(2**3)
# Out:
# 6
# 8

# %%
# program to display multiplication table for 2,3,4,5,6,7,8,9
for i in range(1,13):
    # print(2, " X ", i, " = ", 2 * i, sep=" ")
    print(f"2 X {i} = {2 * i}")
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 2 X 10 = 20
# 2 X 11 = 22
# 2 X 12 = 24

# %%
for i in range(1,13):
    print(f"5 X {i} = {i *5}")
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
# 5 X 11 = 55
# 5 X 12 = 60

# %%
i = 1
while i <= 12:
    print(f"7 x {i} = {i *7}")
    i = i +1
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 7 x 11 = 77
# 7 x 12 = 84

# %%
Python1 = "i love python"
for i in range(1,101):
    print(i,Python1)

# %%
love = 1
#love2 = "i love python"
while love <= 100:
    print(love, "i love python")
    love = love + 1

# %% [markdown]
# ### modules

# %%
import os
import platform
platform.platform()
# Out:
# 'Windows-10-10.0.19045-SP0'
